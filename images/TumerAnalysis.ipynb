# %%
#Load Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
print("Done")
# Out:
# Done

# %%
#Load Dataset
illnessdata=pd.read_csv('./illnessstudy.csv')
illnessdata.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
#Show Key Statistics
illnessdata.describe().T
# Out:
#                          count        mean         std         min  \
# radius_mean              569.0   14.127292    3.524049    6.981000
# texture_mean             569.0   19.289649    4.301036    9.710000
# perimeter_mean           569.0   91.969033   24.298981   43.790000
# area_mean                569.0  654.889104  351.914129  143.500000
# smoothness_mean          569.0    0.096360    0.014064    0.052630
# compactness_mean         569.0    0.104341    0.052813    0.019380
# concavity_mean           569.0    0.088799    0.079720    0.000000
# concave points_mean      569.0    0.048919    0.038803    0.000000
# symmetry_mean            569.0    0.181162    0.027414    0.106000
# fractal_dimension_mean   569.0    0.062798    0.007060    0.049960
# radius_se                569.0    0.405172    0.277313    0.111500
# texture_se               569.0    1.216853    0.551648    0.360200
# perimeter_se             569.0    2.866059    2.021855    0.757000
# ...

# %%
#Create x and y variables
x=illnessdata.drop('diagnosis', axis=1).to_numpy()
y=illnessdata['diagnosis'].to_numpy()

#Create Training and Test Datasets
from sklearn.model_selection import train_test_split
x_train, x_test,y_train, y_test = train_test_split(x, y, stratify=y,test_size=0.2,random_state=100)

#Scale the Data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train2 = sc.fit_transform(x_train)
x_test2 = sc.transform(x_test)
print("Done")
# Out:
# Done

# %%
#Script for SVM 
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix  

for name,method in [('SVM', SVC(kernel='linear',random_state=100))]: 
    method.fit(x_train2,y_train)
    predict = method.predict(x_test2)    
    print('\nEstimator: {}'.format(name)) 
    print(confusion_matrix(y_test,predict))  
    print(classification_report(y_test,predict,zero_division=0))
# Out:
# Estimator: SVM
# [[70  2]
#  [ 3 39]]
#               precision    recall  f1-score   support
#
#            B       0.96      0.97      0.97        72
#            M       0.95      0.93      0.94        42
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114

# %%
#Script for Logistic Regression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, plot_roc_curve  

name = 'Logistic Regression'
method = LogisticRegression(solver='liblinear',random_state=100)

method.fit(x_train2,y_train)
predict = method.predict(x_test2)
target_names=['B','M']
print(confusion_matrix(y_test,predict))  
print(classification_report(y_test,predict,target_names=target_names))
plot_roc_curve(method, x_test2, y_test)
# Out:
# [[70  2]
#  [ 1 41]]
#               precision    recall  f1-score   support
#
#            B       0.99      0.97      0.98        72
#            M       0.95      0.98      0.96        42
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114

# %%
#Script for Decision Tree
from sklearn.tree import DecisionTreeClassifier  

for name,method in [('DT', DecisionTreeClassifier(random_state=100))]: 
    method.fit(x_train2,y_train)
    predict = method.predict(x_test2)
    print('\nEstimator: {}'.format(name)) 
    print(confusion_matrix(y_test,predict))  
    print(classification_report(y_test,predict))
# Out:
# Estimator: DT
# [[67  5]
#  [ 4 38]]
#               precision    recall  f1-score   support
#
#            B       0.94      0.93      0.94        72
#            M       0.88      0.90      0.89        42
#
#     accuracy                           0.92       114
#    macro avg       0.91      0.92      0.92       114
# weighted avg       0.92      0.92      0.92       114

# %%
# histograms for insights
#Variable1 - (radius_mean)
illnessdata['radius_mean'].hist()

#statistic markings
plt.axvline(x=illnessdata['radius_mean'].mean(),color='b', linestyle='dashed', linewidth=2, label='mean')
plt.axvline(x=illnessdata['radius_mean'].std(),color='y', linestyle='-', linewidth=2, label='Standard Deviation')
plt.axvline(x=illnessdata['radius_mean'].min(),color='r', linestyle='dashed', linewidth=2, label='min')
plt.axvline(x=illnessdata['radius_mean'].max(),color='k', linestyle='-', linewidth=2, label='max')
plt.axvline(x=13.37,color='k', linestyle='dashed', linewidth=2, label='median')

#Title and Labels
plt.title("Histogram of radius_mean")
plt.xlabel('radius_mean');
plt.ylabel('Frequency');

#Legend 
plt.legend(bbox_to_anchor=(0.5, 1), loc="upper left")
plt.show()

#Variable2 - (perimeter_mean)-----------------------------------------
illnessdata['perimeter_mean'].hist()

#statistic markings
plt.axvline(x=illnessdata['perimeter_mean'].mean(),color='b', linestyle='dashed', linewidth=2, label='mean')
plt.axvline(x=illnessdata['perimeter_mean'].std(),color='y', linestyle='-', linewidth=2, label='Standard Deviation')
plt.axvline(x=illnessdata['perimeter_mean'].min(),color='r', linestyle='dashed', linewidth=2, label='min')
plt.axvline(x=illnessdata['perimeter_mean'].max(),color='k', linestyle='-', linewidth=2, label='max')
plt.axvline(x=86.24,color='k', linestyle='dashed', linewidth=2, label='median')

#Title and Labels
plt.title("Histogram of perimeter_mean")
plt.xlabel('perimeter_mean');
plt.ylabel('Frequency');

#Legend 
plt.legend(bbox_to_anchor=(0.5, 1), loc="upper left")
plt.show()

#Variable3 - (area_mean)-----------------------------------------
illnessdata['area_mean'].hist()

#statistic markings
plt.axvline(x=illnessdata['area_mean'].mean(),color='b', linestyle='dashed', linewidth=2, label='mean')
plt.axvline(x=illnessdata['area_mean'].std(),color='y', linestyle='-', linewidth=2, label='Standard Deviation')
plt.axvline(x=illnessdata['area_mean'].min(),color='r', linestyle='dashed', linewidth=2, label='min')
plt.axvline(x=illnessdata['area_mean'].max(),color='k', linestyle='-', linewidth=2, label='max')
plt.axvline(x=551.1,color='k', linestyle='dashed', linewidth=2, label='median')

#Title and Labels
plt.title("Histogram of area_mean")
plt.xlabel('area_mean');
plt.ylabel('Frequency');

#Legend 
plt.legend(bbox_to_anchor=(0.5, 1), loc="upper left")
plt.show()

#Variable4 - (symmetry_mean)-----------------------------------------
illnessdata['symmetry_mean'].hist()

#statistic markings
plt.axvline(x=illnessdata['symmetry_mean'].mean(),color='b', linestyle='dashed', linewidth=2, label='mean')
plt.axvline(x=illnessdata['symmetry_mean'].std(),color='y', linestyle='-', linewidth=2, label='Standard Deviation')
plt.axvline(x=illnessdata['symmetry_mean'].min(),color='r', linestyle='dashed', linewidth=2, label='min')
plt.axvline(x=illnessdata['symmetry_mean'].max(),color='k', linestyle='-', linewidth=2, label='max')
plt.axvline(x=0.1792,color='k', linestyle='dashed', linewidth=2, label='median')

#Title and Labels
plt.title("Histogram of symmetry_mean")
plt.xlabel('symmetry_mean');
plt.ylabel('Frequency');

#Legend 
plt.legend(bbox_to_anchor=(0.5, 1), loc="upper left")
plt.show()

#Variable 5- (compactness_mean)-----------------------------------------
illnessdata['compactness_mean'].hist()

#statistic markings
plt.axvline(x=illnessdata['compactness_mean'].mean(),color='b', linestyle='dashed', linewidth=2, label='mean')
plt.axvline(x=illnessdata['compactness_mean'].std(),color='y', linestyle='-', linewidth=2, label='Standard Deviation')
plt.axvline(x=illnessdata['compactness_mean'].min(),color='r', linestyle='dashed', linewidth=2, label='min')
plt.axvline(x=illnessdata['compactness_mean'].max(),color='k', linestyle='-', linewidth=2, label='max')
plt.axvline(x=0.09263,color='k', linestyle='dashed', linewidth=2, label='median')

#Title and Labels
plt.title("Histogram of compactness_mean")
plt.xlabel('compactness_mean');
plt.ylabel('Frequency');

#Legend 
plt.legend(bbox_to_anchor=(0.5, 1), loc="upper left")
plt.show()
